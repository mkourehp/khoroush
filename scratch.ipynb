# %%
music()
# Out:
# d
# [{'note': np.str_('d'), 'duration': 4},
#  {'note': np.str_('d'), 'duration': 4},
#  {'note': np.str_('d'), 'duration': 8},
#  {'note': np.str_('e'), 'duration': 8},
#  {'note': np.str_('d'), 'duration': 4},
#  {'note': np.str_('c'), 'duration': 4},
#  {'note': np.str_('d'), 'duration': 8},
#  {'note': np.str_('e'), 'duration': 8},
#  {'note': np.str_('d'), 'duration': 4},
#  {'note': np.str_('d'), 'duration': 4},
#  {'note': np.str_('c'), 'duration': 8},
#  {'note': np.str_('c'), 'duration': 8},
#  {'note': np.str_('d'), 'duration': 4}]

# %%
import time

from pysinewave import SineWave

# Create a sine wave, with a starting pitch of 12, and a pitch change speed of 10/second.
sinewave = SineWave(pitch = 12, pitch_per_second = 10)

# Turn the sine wave on.
sinewave.play()

# Sleep for 2 seconds, as the sinewave keeps playing.
time.sleep(2)

# Set the goal pitch to -5.
sinewave.set_pitch(-5)

# Sleep for 3 seconds, as the sinewave smoothly slides its pitch down from 12 to -5, and stays there.
time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# PortAudioError                            Traceback (most recent call last)
# Cell In[1], line 6
#       3 from pysinewave import SineWave
#       5 # Create a sine wave, with a starting pitch of 12, and a pitch change speed of 10/second.
# ----> 6 sinewave = SineWave(pitch = 12, pitch_per_second = 10)
#       8 # Turn the sine wave on.
#       9 sinewave.play()
#
# File ~/Music/khoroush/.ve/lib/python3.10/site-packages/pysinewave/sinewave.py:22, in SineWave.__init__(self, pitch, pitch_per_second, decibels, decibels_per_second, channels, channel_side, samplerate)
#      16 self.sinewave_generator = sinewave_generator.SineWaveGenerator(
#      17                             pitch=pitch, pitch_per_second=pitch_per_second,
#      18                             decibels = decibels, decibels_per_second=decibels_per_second,
#      19                             samplerate=samplerate)
#      21 # Create the output stream
# ---> 22 self.output_stream = sd.OutputStream(channels=channels, callback= lambda *args: self._callback(*args),
#      23                         samplerate=samplerate)
#      25 self.channels = channels
#      27 if channel_side == 'r':
#
# File ~/Music/khoroush/.ve/lib/python3.10/site-packages/sounddevice.py:1515, in OutputStream.__init__(self, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback)
#    1483 def __init__(self, samplerate=None, blocksize=None,
#    1484              device=None, channels=None, dtype=None, latency=None,
#    1485              extra_settings=None, callback=None, finished_callback=None,
#    1486              clip_off=None, dither_off=None, never_drop_input=None,
#    1487              prime_output_buffers_using_stream_callback=None):
#    1488     """PortAudio output stream (using NumPy).
#    1489
#    1490     This has the same methods and attributes as `Stream`, except
#    (...)
#    1513
#    1514     """
# -> 1515     _StreamBase.__init__(self, kind='output', wrap_callback='array',
#    1516                          **_remove_self(locals()))
#
# File ~/Music/khoroush/.ve/lib/python3.10/site-packages/sounddevice.py:828, in _StreamBase.__init__(self, kind, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback, userdata, wrap_callback)
#     825         samplerate = isamplerate
#     826 else:
#     827     parameters, self._dtype, self._samplesize, samplerate = \
# --> 828         _get_stream_parameters(kind, device, channels, dtype, latency,
#     829                                extra_settings, samplerate)
#     830     self._device = parameters.device
#     831     self._channels = parameters.channelCount
#
# File ~/Music/khoroush/.ve/lib/python3.10/site-packages/sounddevice.py:2708, in _get_stream_parameters(kind, device, channels, dtype, latency, extra_settings, samplerate)
#    2705 if samplerate is None:
#    2706     samplerate = default.samplerate
# -> 2708 info = query_devices(device)
#    2709 if channels is None:
#    2710     channels = info['max_' + kind + '_channels']
#
# File ~/Music/khoroush/.ve/lib/python3.10/site-packages/sounddevice.py:572, in query_devices(device, kind)
#     570 info = _lib.Pa_GetDeviceInfo(device)
#     571 if not info:
# --> 572     raise PortAudioError(f'Error querying device {device}')
#     573 assert info.structVersion == 2
#     574 name_bytes = _ffi.string(info.name)
#
# PortAudioError: Error querying device -1
